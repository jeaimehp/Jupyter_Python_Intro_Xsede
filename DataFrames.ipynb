# %% [markdown]
# # DataFrames
#
# A DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). In short it allows easy creation, manipulation, and saving of data. For this example we will be using the very popular module named Pandas.
#
# ## Import the `pandas` module and import data from a file to a DataFrame

# %%
import pandas as pd
dataset = pd.read_csv("data/datafile.csv")

# %%
dataset
# Out:
#     Unnamed: 0      A      B      C      D      E      F      G      H      I  \
# 0            0  2.576  3.534  4.169  4.211  0.591  1.007  0.328  4.551  0.863
# 1            1  0.083  0.493  2.810  3.077  2.551  0.922  1.832  0.635  4.215
# 2            2  0.365  2.792  0.874  0.483  2.410  2.573  4.099  2.209  0.172
# 3            3  0.431  1.765  4.320  2.454  2.646  2.844  0.480  1.932  1.564
# 4            4  4.841  1.685  2.488  3.867  1.483  4.094  4.059  0.007  4.998
# 5            5  3.062  4.228  0.287  2.021  0.673  1.790  1.526  3.714  2.555
# 6            6  0.643  4.299  2.096  1.762  2.642  0.114  0.201  1.151  0.211
# 7            7  0.815  4.187  3.658  0.342  1.479  1.790  3.294  1.215  4.635
# 8            8  1.380  0.622  4.588  2.912  4.193  0.811  2.208  1.461  4.999
# 9            9  4.288  4.584  1.815  1.007  3.839  1.938  1.752  4.889  3.618
# 10          10  3.291  0.409  3.216  4.702  2.137  4.628  3.080  0.195  3.982
# ...

# %%
dataset.describe()
# Out:
#        Unnamed: 0          A         B          C          D          E  \
# count   25.000000  25.000000  25.00000  25.000000  25.000000  25.000000
# mean    12.000000   2.236800   2.04552   2.727920   2.773840   2.438400
# std      7.359801   1.441089   1.37526   1.342604   1.254751   1.270226
# min      0.000000   0.083000   0.03100   0.284000   0.342000   0.373000
# 25%      6.000000   0.921000   0.85800   1.815000   1.891000   1.479000
# 50%     12.000000   2.169000   1.70100   2.791000   2.908000   2.642000
# 75%     18.000000   3.291000   3.12100   3.658000   3.867000   3.602000
# max     24.000000   4.841000   4.58400   4.626000   4.702000   4.193000
#
#                F          G          H          I          J
# count  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    2.414320   2.450000   2.572960   2.603960   2.353280
# std     1.497071   1.436256   1.683039   1.676387   1.264716
# min     0.013000   0.201000   0.007000   0.172000   0.109000
# ...

# %%
dataset.dtypes
# Out:
# Unnamed: 0      int64
# A             float64
# B             float64
# C             float64
# D             float64
# E             float64
# F             float64
# G             float64
# H             float64
# I             float64
# J             float64
# dtype: object

# %%
import matplotlib
import matplotlib.pyplot as plt

dataset.plot()

# %%
dataset2 = dataset['J']*1000

# %%
dataset2
# Out:
# 0     4443.0
# 1      109.0
# 2     2565.0
# 3     2141.0
# 4     1389.0
# 5     3355.0
# 6     2958.0
# 7     2435.0
# 8     3037.0
# 9     3176.0
# 10    1545.0
# 11     607.0
# 12    2156.0
# 13    3904.0
# 14    1873.0
# 15     182.0
# 16    2146.0
# 17    1769.0
# 18    3482.0
# 19    3032.0
# 20    2353.0
# 21    4921.0
# 22    3470.0
# 23    1140.0
# 24     644.0
# Name: J, dtype: float64

# %%
dataset2.to_csv("data/dataset2.csv")

# %%
# %ls data
# Out:
# datafile.csv  dataset2.csv
